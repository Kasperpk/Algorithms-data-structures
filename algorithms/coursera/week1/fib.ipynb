# %%
memo = {}
n = 3

# %%
if n in memo:
    print('yes')
else:
    print('not')
# Out:
# not

# %%
a = 8
b = 15

# %%
uneven = True
if a > b:
    c=a
    while uneven:
        if c%b == 0:
            uneven = False
        else:
            c= c*2
if b > a:
    c=b
    while uneven:
        if c%a == 0:
            uneven = False
        else:
            c = c*2

# %%
def fibonacci(n):
    if n <= 1:
        return n

    prev, curr = 0, 1
    for i in range(1, n):
        prev, curr = curr, prev + curr

    return curr

# %%
fibonacci(5)
# Out:
# 1
# 0
# 1
# 2
# 1
# 1
# 3
# 1
# 2
# 4
# 2
# 3
# 5
