# %%
integers = [1,4,5,2,9,6]

# %%
sorted(integers)
# Out:
# [1, 2, 4, 5, 6, 34]

# %%
integers
# Out:
# [1, 4, 5, 2, 34, 6]

# %%
integers.sort()

# %%
integers
# Out:
# [1, 2, 4, 5, 6, 34]

# %%
def maximum_salary(integers):
    sorted_integers = sorted(integers,reverse=True)
    return ''.join([str(integer) for integer in sorted_integers])

# %%
maximum_salary(integers)
# Out:
# '965421'
