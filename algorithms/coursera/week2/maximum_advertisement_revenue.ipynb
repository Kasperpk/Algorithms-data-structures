# %%
def maximum_advertisement_revenue(prices, clicks):
    prices = sorted(prices)
    clicks = sorted(clicks)
    sum = 0
    for index in range(0, len(prices)):
        sum = sum + prices[index] * clicks[index]

    return sum

# %%
maximum_advertisement_revenue([23],[39])
# Out:
# 897

# %%
maximum_advertisement_revenue([2,3,9],[7,4,2])
# Out:
# 79

# %%
import itertools

# %%
rows = itertools.count(2, 2.5)

# %%
rows.__next__()
# Out:
# 22.0

# %%
next(rows)
# Out:
# 32.0
