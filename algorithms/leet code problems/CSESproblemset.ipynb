# %%
def distinct_numbers(numbers):
    return len(set(numbers))

# %%
def merge_sort(numbers):
    if len(numbers) <= 1:
        return numbers

    middle = len(numbers)//2
    left_half = numbers[:middle]
    right_half = numbers[middle:]

    sorted_left = merge_sort(left_half)
    sorted_right = merge_sort(right_half)

    return merge(sorted_left, sorted_right)

def merge(left, right):
    result = []

    # pointers to keep track of where to insert numbers in array
    index = pointer = 0

    while index < len(left) and pointer < len(right):

        if left[index] < right[pointer]:
            result.append(left[index])
            index += 1
        else:
            result.append(right[pointer])
            pointer += 1

    result.extend(left[index:])
    result.extend(right[pointer:])

    return result

# %%
sorted_array = merge_sort([3,7,6,-10,15,23.5, 55,-13])

# %% [markdown]
# I tried this naive algorithm for the apartments problem. It was doing fine on smaller input sizes but hit a time limit on certain input sizes. I consulted the antropic language model and it helped, because it allowed me to create an algorithm which performs much better.
#
# First of all it uses the built-in sorted() algorithm instead of merge-sort. Secondly it uses a different technique to control flow the program using two pointers. Thirdly it avoids having to remove the items which requires a amount of work itself that is *O(n)*.
#
# * sorted() instead of merge sort C-speed vs Python-speed, ~10–50× faster
#
# One of the great things about this algorithm is that it uses the sorted() and that is implemented using C and so when called have a direct translation and does not have the overhead of having to be interpreted.
#
#
# * Two pointers, no resetO(n+m) instead of O(n²)
#
# The two-pointer progression that this algorithm introduces i was not able to really grasp at first. It got better after  i asked for help to understand it, but still it's abit off.
#
#
# * No .remove() calls Eliminates O(n) scans per match
#
# It makes sense that the extra calls here produces extra work which is unecessary. In that way algorithms are brilliant and very honest about what is smart and what is not whereas us people can be very reluctant to change even when it's obvious that we should.

# %%
def apartments(allowed_difference, desired_sizes, apartment_sizes):

    sorted_apartments = merge_sort(apartment_sizes)
    sorted_applications = merge_sort(desired_sizes)
    number_of_apartments_occupied = 0
    apartment_index = 0
    application_index = 0
    while sorted_apartments and sorted_applications:
            print(f"The current index of apartments is {apartment_index} and the current list of apartments is {sorted_apartments}")
            print(f"The current index of applicatants is {application_index} and the current list of applicants is {sorted_applications}")
            difference = sorted_apartments[apartment_index] - sorted_applications[application_index]
            print(f"The difference between the current apartment size and desired is {sorted_apartments[apartment_index] - sorted_applications[application_index]}")
            if abs(difference) <= allowed_difference:
                number_of_apartments_occupied = number_of_apartments_occupied + 1
                sorted_apartments.remove(sorted_apartments[apartment_index])
                sorted_applications.remove(sorted_applications[application_index])
                application_index = 0
            else:
                # if we have reached the final element in applications
                # then reset the application index and progress the
                # apartment
                if application_index + 1 > len(sorted_applications) - 1:
                    application_index = 0
                    sorted_apartments.remove(sorted_apartments[apartment_index])

                else:
                    application_index += 1

    return number_of_apartments_occupied

# %%
apartments(10, [90,41,20,39,49,21,35,31,74,86],[14,24,24,7,82,85,82,4,60,95])
# Out:
# The current index of apartments is 0 and the current list of apartments is [4, 7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 0 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -16
# The current index of apartments is 0 and the current list of apartments is [4, 7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 1 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -17
# The current index of apartments is 0 and the current list of apartments is [4, 7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 2 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -27
# The current index of apartments is 0 and the current list of apartments is [4, 7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 3 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -31
# The current index of apartments is 0 and the current list of apartments is [4, 7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 4 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -35
# The current index of apartments is 0 and the current list of apartments is [4, 7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 5 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -37
# The current index of apartments is 0 and the current list of apartments is [4, 7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 6 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -45
# The current index of apartments is 0 and the current list of apartments is [4, 7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 7 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -70
# The current index of apartments is 0 and the current list of apartments is [4, 7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 8 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -82
# The current index of apartments is 0 and the current list of apartments is [4, 7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 9 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -86
# The current index of apartments is 0 and the current list of apartments is [7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 0 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -13
# The current index of apartments is 0 and the current list of apartments is [7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 1 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -14
# The current index of apartments is 0 and the current list of apartments is [7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 2 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -24
# The current index of apartments is 0 and the current list of apartments is [7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 3 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -28
# The current index of apartments is 0 and the current list of apartments is [7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 4 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -32
# The current index of apartments is 0 and the current list of apartments is [7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 5 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -34
# The current index of apartments is 0 and the current list of apartments is [7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 6 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -42
# The current index of apartments is 0 and the current list of apartments is [7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 7 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -67
# The current index of apartments is 0 and the current list of apartments is [7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 8 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -79
# The current index of apartments is 0 and the current list of apartments is [7, 14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 9 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -83
# The current index of apartments is 0 and the current list of apartments is [14, 24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 0 and the current list of applicants is [20, 21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -6
# Because they apartment is within range we remove them from list
# The apartment list now looks like this [24, 24, 60, 82, 82, 85, 95]
# The applicant list now looks like this [21, 31, 35, 39, 41, 49, 74, 86, 90]
# The current index of apartments is 0 and the current list of apartments is [24, 24, 60, 82, 82, 85, 95]
# The current index of applicatants is 0 and the current list of applicants is [21, 31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is 3
# Because they apartment is within range we remove them from list
# The apartment list now looks like this [24, 60, 82, 82, 85, 95]
# The applicant list now looks like this [31, 35, 39, 41, 49, 74, 86, 90]
# The current index of apartments is 0 and the current list of apartments is [24, 60, 82, 82, 85, 95]
# The current index of applicatants is 0 and the current list of applicants is [31, 35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -7
# Because they apartment is within range we remove them from list
# The apartment list now looks like this [60, 82, 82, 85, 95]
# The applicant list now looks like this [35, 39, 41, 49, 74, 86, 90]
# The current index of apartments is 0 and the current list of apartments is [60, 82, 82, 85, 95]
# The current index of applicatants is 0 and the current list of applicants is [35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is 25
# The current index of apartments is 0 and the current list of apartments is [60, 82, 82, 85, 95]
# The current index of applicatants is 1 and the current list of applicants is [35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is 21
# The current index of apartments is 0 and the current list of apartments is [60, 82, 82, 85, 95]
# The current index of applicatants is 2 and the current list of applicants is [35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is 19
# The current index of apartments is 0 and the current list of apartments is [60, 82, 82, 85, 95]
# The current index of applicatants is 3 and the current list of applicants is [35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is 11
# The current index of apartments is 0 and the current list of apartments is [60, 82, 82, 85, 95]
# The current index of applicatants is 4 and the current list of applicants is [35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -14
# The current index of apartments is 0 and the current list of apartments is [60, 82, 82, 85, 95]
# The current index of applicatants is 5 and the current list of applicants is [35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -26
# The current index of apartments is 0 and the current list of apartments is [60, 82, 82, 85, 95]
# The current index of applicatants is 6 and the current list of applicants is [35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is -30
# The current index of apartments is 0 and the current list of apartments is [82, 82, 85, 95]
# The current index of applicatants is 0 and the current list of applicants is [35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is 47
# The current index of apartments is 0 and the current list of apartments is [82, 82, 85, 95]
# The current index of applicatants is 1 and the current list of applicants is [35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is 43
# The current index of apartments is 0 and the current list of apartments is [82, 82, 85, 95]
# The current index of applicatants is 2 and the current list of applicants is [35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is 41
# The current index of apartments is 0 and the current list of apartments is [82, 82, 85, 95]
# The current index of applicatants is 3 and the current list of applicants is [35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is 33
# The current index of apartments is 0 and the current list of apartments is [82, 82, 85, 95]
# The current index of applicatants is 4 and the current list of applicants is [35, 39, 41, 49, 74, 86, 90]
# The difference between the current apartment size and desired is 8
# Because they apartment is within range we remove them from list
# The apartment list now looks like this [82, 85, 95]
# The applicant list now looks like this [35, 39, 41, 49, 86, 90]
# The current index of apartments is 0 and the current list of apartments is [82, 85, 95]
# The current index of applicatants is 0 and the current list of applicants is [35, 39, 41, 49, 86, 90]
# The difference between the current apartment size and desired is 47
# The current index of apartments is 0 and the current list of apartments is [82, 85, 95]
# The current index of applicatants is 1 and the current list of applicants is [35, 39, 41, 49, 86, 90]
# The difference between the current apartment size and desired is 43
# The current index of apartments is 0 and the current list of apartments is [82, 85, 95]
# The current index of applicatants is 2 and the current list of applicants is [35, 39, 41, 49, 86, 90]
# The difference between the current apartment size and desired is 41
# The current index of apartments is 0 and the current list of apartments is [82, 85, 95]
# The current index of applicatants is 3 and the current list of applicants is [35, 39, 41, 49, 86, 90]
# The difference between the current apartment size and desired is 33
# The current index of apartments is 0 and the current list of apartments is [82, 85, 95]
# The current index of applicatants is 4 and the current list of applicants is [35, 39, 41, 49, 86, 90]
# The difference between the current apartment size and desired is -4
# Because they apartment is within range we remove them from list
# The apartment list now looks like this [85, 95]
# The applicant list now looks like this [35, 39, 41, 49, 90]
# The current index of apartments is 0 and the current list of apartments is [85, 95]
# The current index of applicatants is 0 and the current list of applicants is [35, 39, 41, 49, 90]
# The difference between the current apartment size and desired is 50
# The current index of apartments is 0 and the current list of apartments is [85, 95]
# The current index of applicatants is 1 and the current list of applicants is [35, 39, 41, 49, 90]
# The difference between the current apartment size and desired is 46
# The current index of apartments is 0 and the current list of apartments is [85, 95]
# The current index of applicatants is 2 and the current list of applicants is [35, 39, 41, 49, 90]
# The difference between the current apartment size and desired is 44
# The current index of apartments is 0 and the current list of apartments is [85, 95]
# The current index of applicatants is 3 and the current list of applicants is [35, 39, 41, 49, 90]
# The difference between the current apartment size and desired is 36
# The current index of apartments is 0 and the current list of apartments is [85, 95]
# The current index of applicatants is 4 and the current list of applicants is [35, 39, 41, 49, 90]
# The difference between the current apartment size and desired is -5
# Because they apartment is within range we remove them from list
# The apartment list now looks like this [95]
# The applicant list now looks like this [35, 39, 41, 49]
# The current index of apartments is 0 and the current list of apartments is [95]
# The current index of applicatants is 0 and the current list of applicants is [35, 39, 41, 49]
# The difference between the current apartment size and desired is 60
# The current index of apartments is 0 and the current list of apartments is [95]
# The current index of applicatants is 1 and the current list of applicants is [35, 39, 41, 49]
# The difference between the current apartment size and desired is 56
# The current index of apartments is 0 and the current list of apartments is [95]
# The current index of applicatants is 2 and the current list of applicants is [35, 39, 41, 49]
# The difference between the current apartment size and desired is 54
# The current index of apartments is 0 and the current list of apartments is [95]
# The current index of applicatants is 3 and the current list of applicants is [35, 39, 41, 49]
# The difference between the current apartment size and desired is 46
# 6

# %%
def apartments_optimized(allowed_difference, desired_sizes, apartment_sizes):
    sorted_apartments = sorted(apartment_sizes)
    sorted_applications = sorted(desired_sizes)

    count = 0
    i = j = 0

    while i < len(sorted_applications) and j < len(sorted_apartments):
        diff = sorted_apartments[j] - sorted_applications[i]
        if abs(diff) <= allowed_difference:
            count += 1
            i += 1
            j += 1
        elif diff < 0:
            j += 1
        else:
            i += 1

    return count


if __name__ == '__main__':
    n,m, allowed_difference = map(int, input().split())
    desired_sizes = list(map(int, input().split()))
    apartment_sizes = list(map(int, input().split()))


    result = apartments_optimized(allowed_difference=allowed_difference, desired_sizes=desired_sizes, apartment_sizes=apartment_sizes)
    print(result)
